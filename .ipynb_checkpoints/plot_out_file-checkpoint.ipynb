# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
run_name='-ENVTUSPENVNTUSP-v0LEN100LR0'

# %%
out = pd.read_csv('out'+run_name, sep=" ", header=None)
out.columns = ['reward', 'seen_reward', 'avg', 'total_timesteps', 'total_seconds', 'length']

# data = pd.read_csv('actions', sep=" ", header=None)
# data.columns = ['reward', 'seen_reward', 'avg', 'total_timesteps', 'total_seconds', 'length']

qvalues = pd.read_csv('Q_values'+run_name, sep=" ", header=None)
qvalues.columns = ['q_min', 'q_mean', 'q_max']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-74c070964082> in <module>()
#       1
# ----> 2 out = pd.read_csv('out'+run_name, sep=" ", header=None)
#       3 out.columns = ['reward', 'seen_reward', 'avg', 'total_timesteps', 'total_seconds', 'length']
#       4
#       5 # data = pd.read_csv('actions', sep=" ", header=None)
#
# ...

# %%
#f = open('probs'+run_name)
f=open('probs-ENVTUSPENVNTUSP-v0LEN100LR0')
triplets=f.read().split()
for i in range(0,len(triplets)): 
    triplets[i]=triplets[i].split(' ')
    A=np.array(triplets)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-53595168db53> in <module>()
#       1 #f = open('probs'+run_name)
# ----> 2 f=open('probs-ENVTUSPENVNTUSP-v0LEN100LR0')
#       3 triplets=f.read().split()
#       4 for i in range(0,len(triplets)):
#       5     triplets[i]=triplets[i].split(' ')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'probs-ENVTUSPENVNTUSP-v0LEN100LR0'

# %%
data[(data.reward>11) ].reward.plot()
data[(data.reward<11) & (data.reward>5)].reward.plot()
data[(data.reward<5) & (data.reward>0)].reward.plot()
data[data.reward<0].reward.plot()

# %%
data.reward.plot()

# %%
data.plot.scatter(x='total_seconds',y='reward')

# %%
data.length.plot()
